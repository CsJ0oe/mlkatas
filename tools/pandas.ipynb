# %% [markdown]
# > This is a self-correcting activity generated by [nbgrader](https://nbgrader.readthedocs.io). Fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Run subsequent cells to check your code.

# %% [markdown]
# ---

# %% [markdown]
# # pandas
#
# (Inspired by an activity in the [Open Machine Learning Course](https://mlcourse.ai/))

# %% [markdown]
# ## Part 1 : Loading data

# %%
# Import base packages
import numpy as np
import pandas as pd

# %% [markdown]
# ### Question
#
# Use Pandas to load the dataset located [here](https://raw.githubusercontent.com/bpesquet/mlkatas/master/_datasets/athlete_events.csv), which was extracted from [this Kaggle competition](https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results/). Store it into a DataFrame named `df_olympics`.

# %%
# YOUR CODE HERE
df_olympics = pd.read_csv("../_datasets/athlete_events.csv")

# %%
print(f'df_olympics: {df_olympics.shape}')

assert isinstance(df_olympics, pd.DataFrame)
assert df_olympics.shape == (271116, 15)
# Out:
# df_olympics: (271116, 15)

# %% [markdown]
# ## Part 2: Exploring data

# %% [markdown]
# ### Question
#
# Print general information about the DataFrame.

# %%
# YOUR CODE HERE
df_olympics.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# ### Question
#
# Print and observe the first 10 records of the dataset.

# %%
# YOUR CODE HERE
df_olympics.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %% [markdown]
# ### Question
#
# Print and observe 5 random records of the dataset.

# %%
# YOUR CODE HERE
df_olympics.sample(5)
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 269963  135063  Tamer Hamed Ali Zinhom Muhammad   M  22.0   190.0    80.0
# 210540  105718                       Franco Sar   M  26.0   188.0    88.0
# 92419    46811                    Akira Hayashi   M  25.0   171.0    72.0
# 242377  121409                        Lajos Tth   M  21.0     NaN     NaN
# 49641    25574                   Thophile David   M  24.0   190.0    82.0
#
#                Team  NOC        Games  Year  Season     City       Sport  \
# 269963        Egypt  EGY  1996 Summer  1996  Summer  Atlanta    Swimming
# 210540        Italy  ITA  1960 Summer  1960  Summer     Roma   Athletics
# 92419         Japan  JPN  2000 Summer  2000  Summer   Sydney    Swimming
# 242377      Hungary  HUN  1936 Summer  1936  Summer   Berlin  Gymnastics
# 49641   Switzerland  SUI  1988 Summer  1988  Summer    Seoul    Swimming
#
#                                          Event Medal
# ...
